# %%
import pandas as pd

# %%
# 2 Main Data Types
series = pd.Series(["BMW", "Toyota", "Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
# Series - 1 Dimensional
colours = pd.Series(["Red", "Blue", "White"])

# %%
colours
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
# DataFrame:- 2 Dimensional
car_data = pd.DataFrame({"car make":series, "Colour":colours})

# %%
car_data
# Out:
#   car make Colour
# 0      BMW    Red
# 1   Toyota   Blue
# 2    Honda  White

# %%
# Import Data
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Exporting a dataFrame
car_sales.to_csv("exported_car_sales.csv", index = False)

# %%
exported_car_sales = pd.read_csv("exported_car_sales.csv")
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # Describe Data

# %%
# Attributes
car_sales.dtypes

# Functions
#Car_sales.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # Functions

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
# car_sales.mean()

# %%
car_prices = pd.Series([3000, 8000, 10000])
car_prices.mean()
# Out:
# 7000.0

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
# # Viewing & Selecting Data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(6)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# .loc & .iloc (.loc refers to index and .iloc refers to positions)
animals = pd.Series(["bird", "dog", "cat", "panda", "snake"],
                   index = [0, 3, 9, 8, 3])
animals
# Out:
# 0     bird
# 3      dog
# 9      cat
# 8    panda
# 3    snake
# dtype: object

# %%
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.loc[9]
# Out:
# 'cat'

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals
# Out:
# 0     bird
# 3      dog
# 9      cat
# 8    panda
# 3    snake
# dtype: object

# %%
animals.iloc[3]
# Out:
# 'panda'

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals
# Out:
# 0     bird
# 3      dog
# 9      cat
# 8    panda
# 3    snake
# dtype: object

# %%
animals.iloc[:3]
# Out:
# 0    bird
# 3     dog
# 9     cat
# dtype: object

# %%
car_sales.iloc[:4]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
#Groupby
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.groupby["Colour"].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 car_sales.groupby["Colour"].mean()
#
# TypeError: 'method' object is not subscriptable

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales.plot()
# Out:
# <Axes: >

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '', regex=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Price"] = car_sales["Price"].str[:-2].astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Price"].plot()
# Out:
# <Axes: >

# %% [markdown]
# # Manipulating Data

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].mean()
# Out:
# 92302.66666666667

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"] = car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())

# %%
car_sales_missing.dropna(inplace = True)

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing.dropna()

# %%
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped.to_csv("car-sales-missing-dropped.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %%
# Column from Series
seats_column = pd.Series([5,5,5,5,5])

# New Column calles seats
car_sales["seats"] = seats_column

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  seats
# 0  toyota  White         150043      4   4000    5.0
# 1   honda    Red          87899      4   5000    5.0
# 2  toyota   Blue          32549      3   7000    5.0
# 3     bmw  Black          11179      5  22000    5.0
# 4  nissan  White         213095      4   3500    5.0
# 5  toyota  Green          99213      4   4500    NaN
# 6   honda   Blue          45698      4   7500    NaN
# 7   honda   Blue          54738      4   7000    NaN
# 8  toyota  White          60000      4   6250    NaN
# 9  nissan  White          31600      4   9700    NaN

# %%
car_sales.fillna(5, inplace = True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  seats
# 0  toyota  White         150043      4   4000    5.0
# 1   honda    Red          87899      4   5000    5.0
# 2  toyota   Blue          32549      3   7000    5.0
# 3     bmw  Black          11179      5  22000    5.0
# 4  nissan  White         213095      4   3500    5.0
# 5  toyota  Green          99213      4   4500    5.0
# 6   honda   Blue          45698      4   7500    5.0
# 7   honda   Blue          54738      4   7000    5.0
# 8  toyota  White          60000      4   6250    5.0
# 9  nissan  White          31600      4   9700    5.0

# %%
# Column from Python List
fuel_economy = [9.2, 7.5, 8.3 ,2.9, 6.8, 6.9, 6.4, 5.8, 4.9, 5.9]
car_sales["Fuel Per 100 KM"] = fuel_economy

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  seats  Fuel Per 100 KM
# 0  toyota  White         150043      4   4000    5.0              9.2
# 1   honda    Red          87899      4   5000    5.0              7.5
# 2  toyota   Blue          32549      3   7000    5.0              8.3
# 3     bmw  Black          11179      5  22000    5.0              2.9
# 4  nissan  White         213095      4   3500    5.0              6.8
# 5  toyota  Green          99213      4   4500    5.0              6.9
# 6   honda   Blue          45698      4   7500    5.0              6.4
# 7   honda   Blue          54738      4   7000    5.0              5.8
# 8  toyota  White          60000      4   6250    5.0              4.9
# 9  nissan  White          31600      4   9700    5.0              5.9

# %%
car_sales["Total Fuel Used (L)"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel Per 100 KM"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  seats  Fuel Per 100 KM  \
# 0  toyota  White         150043      4   4000    5.0              9.2
# 1   honda    Red          87899      4   5000    5.0              7.5
# 2  toyota   Blue          32549      3   7000    5.0              8.3
# 3     bmw  Black          11179      5  22000    5.0              2.9
# 4  nissan  White         213095      4   3500    5.0              6.8
# 5  toyota  Green          99213      4   4500    5.0              6.9
# 6   honda   Blue          45698      4   7500    5.0              6.4
# 7   honda   Blue          54738      4   7000    5.0              5.8
# 8  toyota  White          60000      4   6250    5.0              4.9
# 9  nissan  White          31600      4   9700    5.0              5.9
#
#    Total Fuel Used (L)
# 0            13803.956
# 1             6592.425
# 2             2701.567
# 3              324.191
# 4            14490.460
# 5             6845.697
# 6             2924.672
# ...

# %%
# Create a column from a single value
car_sales["Number of Wheels"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  seats  Fuel Per 100 KM  \
# 0  toyota  White         150043      4   4000    5.0              9.2
# 1   honda    Red          87899      4   5000    5.0              7.5
# 2  toyota   Blue          32549      3   7000    5.0              8.3
# 3     bmw  Black          11179      5  22000    5.0              2.9
# 4  nissan  White         213095      4   3500    5.0              6.8
# 5  toyota  Green          99213      4   4500    5.0              6.9
# 6   honda   Blue          45698      4   7500    5.0              6.4
# 7   honda   Blue          54738      4   7000    5.0              5.8
# 8  toyota  White          60000      4   6250    5.0              4.9
# 9  nissan  White          31600      4   9700    5.0              5.9
#
#    Total Fuel Used (L)  Number of Wheels
# 0            13803.956                 4
# 1             6592.425                 4
# 2             2701.567                 4
# ...

# %%
car_sales = car_sales.drop("Total Fuel Used", axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 car_sales = car_sales.drop("Total Fuel Used", axis = 1)
#
# File ~\Favorites\Sample_project_1\env\lib\site-packages\pandas\core\frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
#    5345             weight  1.0     0.8
#    5346     """
# -> 5347     return super().drop(
#    5348         labels=labels,
#    5349         axis=axis,
#    5350         index=index,
#    5351         columns=columns,
#    5352         level=level,
#    5353         inplace=inplace,
# ...

# %%
car_sales

# %%
car_sales_suffled = car_sales.sample(frac=1)

# %%
car_sales_suffled
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  seats  Fuel Per 100 KM  \
# 3     bmw  Black          11179      5  22000    5.0              2.9
# 7   honda   Blue          54738      4   7000    5.0              5.8
# 9  nissan  White          31600      4   9700    5.0              5.9
# 0  toyota  White         150043      4   4000    5.0              9.2
# 8  toyota  White          60000      4   6250    5.0              4.9
# 2  toyota   Blue          32549      3   7000    5.0              8.3
# 5  toyota  Green          99213      4   4500    5.0              6.9
# 6   honda   Blue          45698      4   7500    5.0              6.4
# 4  nissan  White         213095      4   3500    5.0              6.8
# 1   honda    Red          87899      4   5000    5.0              7.5
#
#    Total Fuel Used (L)  Number of Wheels
# 3              324.191                 4
# 7             3174.804                 4
# 9             1864.400                 4
# ...

# %%
car_sales_suffled.sample(frac=0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  seats  Fuel Per 100 KM  \
# 0  toyota  White         150043      4   4000    5.0              9.2
# 6   honda   Blue          45698      4   7500    5.0              6.4
#
#    Total Fuel Used (L)  Number of Wheels
# 0            13803.956                 4
# 6             2924.672                 4

# %%
car_sales_suffled.reset_index()
# Out:
#    index    Make Colour  Odometer (KM)  Doors  Price  seats  Fuel Per 100 KM  \
# 0      3     bmw  Black          11179      5  22000    5.0              2.9
# 1      7   honda   Blue          54738      4   7000    5.0              5.8
# 2      9  nissan  White          31600      4   9700    5.0              5.9
# 3      0  toyota  White         150043      4   4000    5.0              9.2
# 4      8  toyota  White          60000      4   6250    5.0              4.9
# 5      2  toyota   Blue          32549      3   7000    5.0              8.3
# 6      5  toyota  Green          99213      4   4500    5.0              6.9
# 7      6   honda   Blue          45698      4   7500    5.0              6.4
# 8      4  nissan  White         213095      4   3500    5.0              6.8
# 9      1   honda    Red          87899      4   5000    5.0              7.5
#
#    Total Fuel Used (L)  Number of Wheels
# 0              324.191                 4
# ...

# %%
car_sales_suffled.reset_index(drop = True, inplace = True)

# %%
car_sales_suffled
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  seats  Fuel Per 100 KM  \
# 0     bmw  Black          11179      5  22000    5.0              2.9
# 1   honda   Blue          54738      4   7000    5.0              5.8
# 2  nissan  White          31600      4   9700    5.0              5.9
# 3  toyota  White         150043      4   4000    5.0              9.2
# 4  toyota  White          60000      4   6250    5.0              4.9
# 5  toyota   Blue          32549      3   7000    5.0              8.3
# 6  toyota  Green          99213      4   4500    5.0              6.9
# 7   honda   Blue          45698      4   7500    5.0              6.4
# 8  nissan  White         213095      4   3500    5.0              6.8
# 9   honda    Red          87899      4   5000    5.0              7.5
#
#    Total Fuel Used (L)  Number of Wheels
# 0              324.191                 4
# 1             3174.804                 4
# 2             1864.400                 4
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  seats  Fuel Per 100 KM  \
# 0  toyota  White         150043      4   4000    5.0              9.2
# 1   honda    Red          87899      4   5000    5.0              7.5
# 2  toyota   Blue          32549      3   7000    5.0              8.3
# 3     bmw  Black          11179      5  22000    5.0              2.9
# 4  nissan  White         213095      4   3500    5.0              6.8
# 5  toyota  Green          99213      4   4500    5.0              6.9
# 6   honda   Blue          45698      4   7500    5.0              6.4
# 7   honda   Blue          54738      4   7000    5.0              5.8
# 8  toyota  White          60000      4   6250    5.0              4.9
# 9  nissan  White          31600      4   9700    5.0              5.9
#
#    Total Fuel Used (L)  Number of Wheels
# 0            13803.956                 4
# 1             6592.425                 4
# 2             2701.567                 4
# ...

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x:x/1.6)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  seats  Fuel Per 100 KM  \
# 0  toyota  White      93776.875      4   4000    5.0              9.2
# 1   honda    Red      54936.875      4   5000    5.0              7.5
# 2  toyota   Blue      20343.125      3   7000    5.0              8.3
# 3     bmw  Black       6986.875      5  22000    5.0              2.9
# 4  nissan  White     133184.375      4   3500    5.0              6.8
# 5  toyota  Green      62008.125      4   4500    5.0              6.9
# 6   honda   Blue      28561.250      4   7500    5.0              6.4
# 7   honda   Blue      34211.250      4   7000    5.0              5.8
# 8  toyota  White      37500.000      4   6250    5.0              4.9
# 9  nissan  White      19750.000      4   9700    5.0              5.9
#
#    Total Fuel Used (L)  Number of Wheels
# 0            13803.956                 4
# 1             6592.425                 4
# 2             2701.567                 4
# ...
